# %%
import pandas as pd

# %%
Dataset = pd.read_excel("/content/bike sales data TCB.xlsx")

# %%
Dataset
# Out:
#      Customer ID    Customer Name Marital Status Gender  Income  Children  \
# 0       CG-12520      Claire Gute              M      F   40000         1
# 1       CG-12520      Claire Gute              M      M   30000         3
# 2       DV-13045  Darrin Van Huff              M      M   80000         5
# 3       SO-20335   Sean O'Donnell              S      M   70000         0
# 4       SO-20335   Sean O'Donnell              S      M   30000         0
# ...          ...              ...            ...    ...     ...       ...
# 1021    GT-14710        Greg Tran              S      F   20000         0
# 1022    GT-14710        Greg Tran              M      F   20000         2
# 1023    PB-19150     Philip Brown              M      M   10000         0
# 1024    HR-14770   Hallie Redmond              S      F   20000         0
# 1025    DE-13255       Deanra Eno              S      M   80000         2
#
#                 Education      Occupation Home Owner  Cars Commute Distance  \
# ...

# %% [markdown]
# #**AGGREGATE FUNCTIONS**

# %%
#Use the `SUM` function to calculate the total income from all customers
Dataset["Income"].sum()
# Out:
# 57670000

# %%
#Use the `AVERAGE` function to find the average income of customers
Dataset["Income"].mean()
# Out:
# 56208.57699805068

# %%
#Use the `MAX` function to identify the maximum income of customers
Dataset["Income"].max()
# Out:
# 170000

# %%
#Use the `MIN` function to find the minimum income
Dataset["Income"].min()
# Out:
# 10000

# %%
#Use the `COUNT` function to count how many income values are available (non-blank)
Dataset["Income"].count()
# Out:
# 1026

# %% [markdown]
# # **TEXT FUNCTIONS**

# %%
#Use the `LEFT` function to extract the first 2 characters from the Customer ID column
Dataset["Customer ID"].str.slice(0,2)
# Out:
# 0       CG
# 1       CG
# 2       DV
# 3       SO
# 4       SO
#         ..
# 1021    GT
# 1022    GT
# 1023    PB
# 1024    HR
# 1025    DE
# Name: Customer ID, Length: 1026, dtype: object

# %%
#Use the `RIGHT` function to extract the last 3 characters of the Customer Name column
Dataset["Customer Name"].str.slice(-3)
# Out:
# 0       ute
# 1       ute
# 2       uff
# 3       ell
# 4       ell
#        ...
# 1021    ran
# 1022    ran
# 1023    own
# 1024    ond
# 1025    Eno
# Name: Customer Name, Length: 1026, dtype: object

# %%
#Use the `LEN` function to find the length of each name in the Customer Name column
Dataset["Customer Name"].str.len()
# Out:
# 0       11
# 1       11
# 2       15
# 3       14
# 4       14
#         ..
# 1021     9
# 1022     9
# 1023    12
# 1024    14
# 1025    10
# Name: Customer Name, Length: 1026, dtype: int64

# %%
#Use the `CONCAT` function (or `TEXTJOIN` if preferred) to combine the Customer Name and Customer ID
Dataset["Customer Name"] + " " + Dataset["Customer ID"]
# Out:
# 0           Claire Gute CG-12520
# 1           Claire Gute CG-12520
# 2       Darrin Van Huff DV-13045
# 3        Sean O'Donnell SO-20335
# 4        Sean O'Donnell SO-20335
#                   ...
# 1021          Greg Tran GT-14710
# 1022          Greg Tran GT-14710
# 1023       Philip Brown PB-19150
# 1024     Hallie Redmond HR-14770
# 1025         Deanra Eno DE-13255
# Length: 1026, dtype: object

# %%
#Use the `TRIM` function to remove any leading or trailing spaces in the Customer Name column
Dataset["Customer Name"].str.strip()
# Out:
# 0           Claire Gute
# 1           Claire Gute
# 2       Darrin Van Huff
# 3        Sean O'Donnell
# 4        Sean O'Donnell
#              ...
# 1021          Greg Tran
# 1022          Greg Tran
# 1023       Philip Brown
# 1024     Hallie Redmond
# 1025         Deanra Eno
# Name: Customer Name, Length: 1026, dtype: object

# %% [markdown]
# # **LOGICAL FUNCTIONS**

# %%
#Use the `IF` function to create a new column labeled "High Income", where customers with an income above $50,000 are marked as “Yes” and those below are marked as “No.”
Dataset["High Income"] = Dataset["Income"].apply(lambda x: "Yes" if x > 50000 else "No")

# %%
def dfincome(income):
  if income>50000:
   return "Yes",
  else:
    return "No"

  Dataset["High Income"] = Dataset["Income"].apply(dfincome)

# %%
Dataset
# Out:
#      Customer ID    Customer Name Marital Status Gender  Income  Children  \
# 0       CG-12520      Claire Gute              M      F   40000         1
# 1       CG-12520      Claire Gute              M      M   30000         3
# 2       DV-13045  Darrin Van Huff              M      M   80000         5
# 3       SO-20335   Sean O'Donnell              S      M   70000         0
# 4       SO-20335   Sean O'Donnell              S      M   30000         0
# ...          ...              ...            ...    ...     ...       ...
# 1021    GT-14710        Greg Tran              S      F   20000         0
# 1022    GT-14710        Greg Tran              M      F   20000         2
# 1023    PB-19150     Philip Brown              M      M   10000         0
# 1024    HR-14770   Hallie Redmond              S      F   20000         0
# 1025    DE-13255       Deanra Eno              S      M   80000         2
#
#                 Education      Occupation Home Owner  Cars Commute Distance  \
# ...

# %%
Dataset["High Income"] = Dataset["Income"].apply(lambda income: "Yes" if income > 50000 else "No")

# %%
Dataset
# Out:
#      Customer ID    Customer Name Marital Status Gender  Income  Children  \
# 0       CG-12520      Claire Gute              M      F   40000         1
# 1       CG-12520      Claire Gute              M      M   30000         3
# 2       DV-13045  Darrin Van Huff              M      M   80000         5
# 3       SO-20335   Sean O'Donnell              S      M   70000         0
# 4       SO-20335   Sean O'Donnell              S      M   30000         0
# ...          ...              ...            ...    ...     ...       ...
# 1021    GT-14710        Greg Tran              S      F   20000         0
# 1022    GT-14710        Greg Tran              M      F   20000         2
# 1023    PB-19150     Philip Brown              M      M   10000         0
# 1024    HR-14770   Hallie Redmond              S      F   20000         0
# 1025    DE-13255       Deanra Eno              S      M   80000         2
#
#                 Education      Occupation Home Owner  Cars Commute Distance  \
# ...

# %%
#Use the `SUMIF` function to calculate the total Income for customers who are married (i.e M)
def dfincome(income):
  # Assuming 'income' is a pandas DataFrame and it contains columns named 'Marital_Status' and 'Income'
  # Replace 'Marital_Status' and 'Income' if your column names are different
    return income[income['Marital Status'] == 'M']['Income'].sum()

    return None

# %%
Dataset.groupby("Marital Status")["Income"].sum()
# Out:
# Marital Status
# M    32210000
# S    25460000
# Name: Income, dtype: int64

# %%
#Use the `COUNTIF` function to count how many customers have an income greater than $50,000
def dfincome(income):
  return income[income['Income'] > 50000]['Income'].count()

# %%
Dataset.groupby("Income")["Income"].count()
# Out:
# Income
# 10000      76
# 20000      78
# 30000     140
# 40000     159
# 50000      40
# 60000     166
# 70000     125
# 80000      94
# 90000      40
# 100000     30
# 110000     16
# 120000     19
# 130000     32
# 150000      4
# 160000      3
# 170000      4
# Name: Income, dtype: int64

# %%
#In a new column named “Age Bracket”, Use the `IFS` function to classify customers age into categories: - Adolescents (0-30), - Middle age (31-54), and - Old (55+)

# %%
Dataset['Age Bracket'] = Dataset['Age'].apply(lambda x: 'Adolescents' if x <= 30 else ('Middle age' if x <= 54 else 'Old'))

# %%
Dataset
# Out:
#      Customer ID    Customer Name Marital Status Gender  Income  Children  \
# 0       CG-12520      Claire Gute              M      F   40000         1
# 1       CG-12520      Claire Gute              M      M   30000         3
# 2       DV-13045  Darrin Van Huff              M      M   80000         5
# 3       SO-20335   Sean O'Donnell              S      M   70000         0
# 4       SO-20335   Sean O'Donnell              S      M   30000         0
# ...          ...              ...            ...    ...     ...       ...
# 1021    GT-14710        Greg Tran              S      F   20000         0
# 1022    GT-14710        Greg Tran              M      F   20000         2
# 1023    PB-19150     Philip Brown              M      M   10000         0
# 1024    HR-14770   Hallie Redmond              S      F   20000         0
# 1025    DE-13255       Deanra Eno              S      M   80000         2
#
#                 Education      Occupation Home Owner  Cars Commute Distance  \
# ...

# %%
#Use the `AND` function to create a new column that checks if a customer’s income is greater than $50,000 and their age is greater than 30

# %%
Dataset['Income >50k and Age >30'] = Dataset.apply(lambda row: row['Income'] > 50000 and row['Age'] > 30, axis=1)

# %%
Dataset
# Out:
#      Customer ID    Customer Name Marital Status Gender  Income  Children  \
# 0       CG-12520      Claire Gute              M      F   40000         1
# 1       CG-12520      Claire Gute              M      M   30000         3
# 2       DV-13045  Darrin Van Huff              M      M   80000         5
# 3       SO-20335   Sean O'Donnell              S      M   70000         0
# 4       SO-20335   Sean O'Donnell              S      M   30000         0
# ...          ...              ...            ...    ...     ...       ...
# 1021    GT-14710        Greg Tran              S      F   20000         0
# 1022    GT-14710        Greg Tran              M      F   20000         2
# 1023    PB-19150     Philip Brown              M      M   10000         0
# 1024    HR-14770   Hallie Redmond              S      F   20000         0
# 1025    DE-13255       Deanra Eno              S      M   80000         2
#
#                 Education      Occupation Home Owner  Cars Commute Distance  \
# ...
